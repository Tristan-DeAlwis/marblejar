# %% [markdown]
# # Prompt
# Suppose a jar contains the same number of black and white marbles. If you reach in and pull out two random marbles, are they more likely to be the same color or different colors?
#
# Using the MarbleJar class,  write a program that will help you solve the problem.
#
# Your program should prompt the user for the initial number of marbles of each color.
#
# Then it should repeatedly draw two marbles, noting when they are the same color and then returning them to the jar.
#
# It should do this some constant number of times (say 1000) and then output the number and percentage of each type of result.

# %%
import random

# %%
class MarbleJar():
    def __init__(self):
        self = []
        
    def MarbleJar(): # initializes jar contents

        Jar = []
        
        print('How many White Marbles?')
        t = int(input())
        while t > 0:
            Jar.append("w")
            t -= 1
            
        print("\nHow many Black Marbles?")
        t = int(input())
        print()
        while t > 0:
            Jar.append("blk")
            t -= 1
        
        random.shuffle(Jar)
            
        MarbleJar.DrawMarble(Jar)
        
            
        if MarbleJar.IsEmpty(Jar):
            print("Jar Empty")
        
        
    def DrawMarble(Jar): # draws and returns color
        no_of_draws = 1000
        i = no_of_draws
        j = 0
        while i > 0:
            m1 = Jar.pop()
            m2 = Jar.pop()
            
            if m1 == m2:
                print("Same Color: ", m1)
                j += 1
                
            Jar.append(m1)
            Jar.append(m2)
            
            random.shuffle(Jar)
            
            i -= 1
        
        print("\nPercentage of Same Color Draws: ", j/no_of_draws*100, "%")
        
#     def void AddMarble (String color): # adds marble to jar
    
    def IsEmpty(Jar): # returns true if empty
        return len(Jar) == 0
    
#     int myNumberBlack, myNumberWhite: # marbles in the jar
#     int myRandom() # random number generator

# %%
MarbleJar.MarbleJar()
# Out:
# How many White Marbles?
# 5
#
# How many Black Marbles?
# 5
#
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  blk
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  w
# Same Color:  w
# Same Color:  blk
# Same Color:  blk
# Same Color:  w
# ...
